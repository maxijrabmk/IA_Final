# %% [markdown]
# # Análisis de datos meteorológicos - Preprocesamiento

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

iscolab = True

# %% [markdown]
# # Corrección de formato de las bases de datos

# %%
if iscolab:
    from google.colab import drive
    drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
if iscolab:
    # %cd "/content/gdrive/MyDrive/Colab Notebooks/IA_Temperatura"
##Se cargan los conjuntos de datos
datosS2_2019 = pd.read_csv("datos/Estacion2_2019.csv",sep=';',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS2_2020 = pd.read_csv("datos/Estacion2_2020.csv",sep=',',names=[ 'ID'])
datosS2_2021 = pd.read_csv("datos/Estacion2_2021.csv",sep=',',names=[ 'ID'])
datosS3_2019 = pd.read_csv("datos/Estacion3_2019.csv",sep=';',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS3_2020 = pd.read_csv("datos/Estacion3_2020.csv",sep=',',names=[ 'ID'])
datosS3_2021 = pd.read_csv("datos/Estacion3_2021.csv",sep=',',names=[ 'ID'])
datosS4_2019 = pd.read_csv("datos/Estacion4_2019.csv",sep=';',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS4_2020 = pd.read_csv("datos/Estacion4_2020.csv",sep=',',names=[ 'ID'])
datosS4_2021 = pd.read_csv("datos/Estacion4_2021.csv",sep=',',names=[ 'ID'])
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/IA_Temperatura

# %%
##En los datasets de 2020 y 2021 los datos tienen ubicados comillas de manera errónea, entonces se eliminan.
datosS2_2020["ID"] = datosS2_2020["ID"].str.replace('"','')
datosS2_2021["ID"] = datosS2_2021["ID"].str.replace('"','')
datosS3_2020["ID"] = datosS3_2020["ID"].str.replace('"','')
datosS3_2021["ID"] = datosS3_2021["ID"].str.replace('"','')
datosS4_2020["ID"] = datosS4_2020["ID"].str.replace('"','')
datosS4_2021["ID"] = datosS4_2021["ID"].str.replace('"','')

# %%
##Se diveden los conjuntos de datos en columnas, con coma como separador
datosS2_2020 = datosS2_2020["ID"].str.split(',',expand=True)
datosS2_2021 = datosS2_2021["ID"].str.split(',',expand=True)
datosS3_2020 = datosS3_2020["ID"].str.split(',',expand=True)
datosS3_2021 = datosS3_2021["ID"].str.split(',',expand=True)
datosS4_2020 = datosS4_2020["ID"].str.split(',',expand=True)
datosS4_2021 = datosS4_2021["ID"].str.split(',',expand=True)

# %%
##Se guardan en csv corregidos los datos con formato correcto
datosS2_2020.to_csv("datos/Estacion2_2020_Corregido.csv",header=False,index=False)
datosS2_2021.to_csv("datos/Estacion2_2021_Corregido.csv",header=False,index=False)
datosS3_2020.to_csv("datos/Estacion3_2020_Corregido.csv",header=False,index=False)
datosS3_2021.to_csv("datos/Estacion3_2021_Corregido.csv",header=False,index=False)
datosS4_2020.to_csv("datos/Estacion4_2020_Corregido.csv",header=False,index=False)
datosS4_2021.to_csv("datos/Estacion4_2021_Corregido.csv",header=False,index=False)

# %%
##Se cargan los conjuntos de datos corregidos
datosS2_2020 = pd.read_csv("datos/Estacion2_2020_Corregido.csv",sep=',',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS2_2021 = pd.read_csv("datos/Estacion2_2021_Corregido.csv",sep=',',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS3_2020 = pd.read_csv("datos/Estacion3_2020_Corregido.csv",sep=',',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS3_2021 = pd.read_csv("datos/Estacion3_2021_Corregido.csv",sep=',',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS4_2020 = pd.read_csv("datos/Estacion4_2020_Corregido.csv",sep=',',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])
datosS4_2021 = pd.read_csv("datos/Estacion4_2021_Corregido.csv",sep=',',names=[ 'ID', 'fecha', 'hora', 'MP1', 'MP2.5', 'MP10', 'Temperatura',' Humedad', 'Presión', 'Batería'])

# %% [markdown]
# # Preprocesamiento

# %%
# %mkdir Imagenes
##Se crean bases de datos con todos los años
datosS2 = pd.concat([datosS2_2019,datosS2_2020,datosS2_2021],ignore_index=True)
datosS3 = pd.concat([datosS3_2019,datosS3_2020,datosS3_2021],ignore_index=True)
datosS4 = pd.concat([datosS4_2019,datosS4_2020,datosS4_2021],ignore_index=True)
# Out:
# mkdir: cannot create directory ‘Imagenes’: File exists

# %%
##Luego, se reemplaza el índice numérico por índices basados en el dato temporal de cada medición
datosS2["datetime"] = pd.to_datetime(datosS2.fecha +" "+datosS2.hora)
datosS2.set_index(["datetime"],drop=True, inplace=True)
datosS2.head()
# Out:
#                      ID       fecha  hora     MP1   MP2.5    MP10  \
# datetime
# 2019-04-17 09:15:00   1  17-04-2019  9:15   5.500   8.429  37.619
# 2019-04-17 09:20:00   2  17-04-2019  9:20   3.889   5.210   7.889
# 2019-04-17 09:25:00   3  17-04-2019  9:25   3.289   5.069  24.629
# 2019-04-17 09:30:00   4  17-04-2019  9:30  11.109  14.259  20.869
# 2019-04-17 09:35:00   5  17-04-2019  9:35  10.659  13.399  15.779
#
#                      Temperatura   Humedad  Presión  Batería
# datetime
# 2019-04-17 09:15:00         24.5      62.5   1002.8       82
# 2019-04-17 09:20:00         25.1      61.3   1002.9       82
# 2019-04-17 09:25:00         25.9      59.1   1001.7       80
# 2019-04-17 09:30:00         26.5      57.4    998.8       80
# 2019-04-17 09:35:00         26.9      56.3   1000.1       80

# %%
datosS3["datetime"] = pd.to_datetime(datosS3.fecha +" "+datosS3.hora)
datosS3.set_index(["datetime"],drop=True, inplace=True)
datosS3.head()
# Out:
#                      ID       fecha  hora     MP1   MP2.5    MP10  \
# datetime
# 2019-07-04 07:50:00   1  07-04-2019  7:50  50.360  68.860  72.369
# 2019-07-04 07:55:00   2  07-04-2019  7:55  43.479  59.889  64.169
# 2019-07-04 08:00:00   3  07-04-2019  8:00  72.489  93.989  97.379
# 2019-07-04 08:05:00   4  07-04-2019  8:05  33.459  44.840  46.379
# 2019-07-04 08:10:00   5  07-04-2019  8:10  30.629  42.099  50.529
#
#                      Temperatura   Humedad  Presión  Batería
# datetime
# 2019-07-04 07:50:00         20.2      75.3   1004.7      100
# 2019-07-04 07:55:00         20.6      74.1   1004.7      100
# 2019-07-04 08:00:00         20.8      74.0   1004.8      100
# 2019-07-04 08:05:00         21.2      71.8   1004.8       99
# 2019-07-04 08:10:00         21.4      72.0   1004.8       99

# %%
datosS4["datetime"] = pd.to_datetime(datosS4.fecha +" "+datosS4.hora)
datosS4.set_index(["datetime"],drop=True, inplace=True)
datosS4.head()
# Out:
#                       ID       fecha  hora     MP1   MP2.5    MP10  \
# datetime
# 2019-01-04 00:00:00  429  01-04-2019  0:00  19.049  24.000  25.239
# 2019-01-04 00:05:00  430  01-04-2019  0:05  18.369  23.739  27.389
# 2019-01-04 00:10:00  431  01-04-2019  0:10  19.180  24.399  24.869
# 2019-01-04 00:15:00  432  01-04-2019  0:15  20.309  26.129  28.149
# 2019-01-04 00:20:00  433  01-04-2019  0:20  19.379  24.559  30.789
#
#                      Temperatura   Humedad  Presión  Batería
# datetime
# 2019-01-04 00:00:00         25.8      78.3   1001.5       90
# 2019-01-04 00:05:00         25.7      78.8   1001.4       90
# 2019-01-04 00:10:00         25.6      79.7   1001.3       90
# 2019-01-04 00:15:00         25.5      81.3   1001.2       90
# 2019-01-04 00:20:00         25.5      83.0   1001.1       90

# %%
##Se visualizan los datos como serie temporal
datosS2["Temperatura"].plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
plt.savefig("Imagenes/Est2RAW.png")

# %%
datosS3["Temperatura"].plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
plt.savefig("Imagenes/Est3RAW.png")

# %%
datosS4["Temperatura"].plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
plt.savefig("Imagenes/Est4RAW.png")

# %%
##Se realiza un muestreo de los datos cada 1 hora.
dfEst2H = datosS2.resample('60min').mean()
dfEst2H = dfEst2H["Temperatura"]
dfEst3H = datosS3.resample('60min').mean()
dfEst3H = dfEst3H["Temperatura"]
dfEst4H = datosS4.resample('60min').mean()
dfEst4H = dfEst4H["Temperatura"]
# Out:
# <ipython-input-15-c3e1d6ebc17c>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfEst2H = datosS2.resample('60min').mean()
# <ipython-input-15-c3e1d6ebc17c>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfEst3H = datosS3.resample('60min').mean()
# <ipython-input-15-c3e1d6ebc17c>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfEst4H = datosS4.resample('60min').mean()

# %%
dfEst2H.head()
# Out:
# datetime
# 2019-01-05 00:00:00    19.116667
# 2019-01-05 01:00:00    19.091667
# 2019-01-05 02:00:00    18.900000
# 2019-01-05 03:00:00    18.658333
# 2019-01-05 04:00:00    18.591667
# Freq: 60T, Name: Temperatura, dtype: float64

# %%
dfEst3H.head()
# Out:
# datetime
# 2019-01-05 00:00:00    19.275000
# 2019-01-05 01:00:00    19.291667
# 2019-01-05 02:00:00    19.116667
# 2019-01-05 03:00:00    18.941667
# 2019-01-05 04:00:00    18.725000
# Freq: 60T, Name: Temperatura, dtype: float64

# %%
dfEst4H.head()
# Out:
# datetime
# 2019-01-04 00:00:00    25.575000
# 2019-01-04 01:00:00    25.625000
# 2019-01-04 02:00:00    25.041667
# 2019-01-04 03:00:00    24.708333
# 2019-01-04 04:00:00    24.525000
# Freq: 60T, Name: Temperatura, dtype: float64

# %%
##Se visualizan los datos muestreados
dfEst2H.plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
plt.savefig("Imagenes/Est2RAW_Res.png")

# %%
dfEst3H.plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
plt.savefig("Imagenes/Est3RAW_Res.png")

# %%
dfEst4H.plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
plt.savefig("Imagenes/Est4RAW_Res.png")

# %%
##Se imprime la cantidad de datos faltantes en los conjuntos de datos
print("En la Estación 2 faltan "+str(dfEst2H.isna().sum())+" datos.")
print("En la Estación 3 faltan "+str(dfEst3H.isna().sum())+" datos.")
print("En la Estación 4 faltan "+str(dfEst4H.isna().sum())+" datos.")
# Out:
# En la Estación 2 faltan 2460 datos.
# En la Estación 3 faltan 2217 datos.
# En la Estación 4 faltan 2090 datos.

# %%
##Se deben llenar los datos faltantes. Para ello, se hará uso de un conjunto de datos de otra
#estación.
datosNasaAsu = pd.read_csv("datos/Temp_Asu20092021.csv",sep=',')
datosNasaAsu["datetime"] = pd.to_datetime(datosNasaAsu.Fecha)
datosNasaAsu.set_index(["datetime"],drop=True, inplace=True)
datosNasaAsu = datosNasaAsu["Temperatura"]
datosNasaAsu.head()
# Out:
# datetime
# 2009-01-01 00:00:00    26.749483
# 2009-01-01 03:00:00    25.956114
# 2009-01-01 06:00:00    23.707357
# 2009-01-01 09:00:00    23.726823
# 2009-01-01 12:00:00    29.606379
# Name: Temperatura, dtype: float64

# %%
##Debido a la gran falta de valores al comienzo del conjunto de datos, entonces se iniciará el análisis
#desde 01/05/2019 00:00:00

# %%
indicesNasa = np.logical_and((datosNasaAsu.index >= pd.to_datetime("05/01/2019 00:00:00")),(datosNasaAsu.index <= pd.to_datetime("31/12/2021 23:00:00")))
indicesEst2 = np.logical_and((dfEst2H.index >= pd.to_datetime("05/01/2019 00:00:00")),(dfEst2H.index <= pd.to_datetime("31/12/2021 23:00:00")))
indicesEst3 = np.logical_and((dfEst3H.index >= pd.to_datetime("05/01/2019 00:00:00")),(dfEst3H.index <= pd.to_datetime("31/12/2021 23:00:00")))
indicesEst4 = np.logical_and((dfEst4H.index >= pd.to_datetime("05/01/2019 00:00:00")),(dfEst4H.index <= pd.to_datetime("31/12/2021 23:00:00")))

# %%
##Con los índices nuevos, se obtienen los nuevos conjuntos de datos delimitados
datosNasa = datosNasaAsu[indicesNasa]
datosEst2 = dfEst2H[indicesEst2]
datosEst3 = dfEst3H[indicesEst3]
datosEst4 = dfEst4H[indicesEst4]
datosNasa.rename("Temp_NASA",inplace=True)
datosEst2.rename("Temp_Est2",inplace=True)
datosEst3.rename("Temp_Est3",inplace=True)
datosEst4.rename("Temp_Est4",inplace=True)
# Out:
# datetime
# 2019-05-01 00:00:00          NaN
# 2019-05-01 01:00:00          NaN
# 2019-05-01 02:00:00          NaN
# 2019-05-01 03:00:00          NaN
# 2019-05-01 04:00:00          NaN
#                          ...
# 2021-12-31 19:00:00    35.658333
# 2021-12-31 20:00:00    34.000000
# 2021-12-31 21:00:00    33.108333
# 2021-12-31 22:00:00    32.116667
# 2021-12-31 23:00:00    31.275000
# Freq: 60T, Name: Temp_Est4, Length: 23424, dtype: float64

# %%
##Se crea un solo dataframe que contenga todos los conjuntos de datos en diferentes columnas
dataframeEstaciones = pd.DataFrame(datosEst2)
dataframeEstaciones = dataframeEstaciones.join(datosEst3)
dataframeEstaciones = dataframeEstaciones.join(datosEst4)
dataframeEstaciones = dataframeEstaciones.join(datosNasa)
dataframeEstaciones
##Se guarda la cantida de datos de la base de datos
N = dataframeEstaciones["Temp_NASA"].shape
N = N[0]

# %%
##Como los datos de la NASA son cada 3 horas, se hace una interpolación lineal
#bajo la suposición de que en 3 horas la temperatura varía de manera lineal aproximadamente.
dataframeEstaciones["Temp_NASA"] = dataframeEstaciones["Temp_NASA"].interpolate(method='linear')
##Como los 2 ultimos datos no pudieron ser interpolados cuadráticamnte, entonces se
#Calculará de manera manual:
m1 = (dataframeEstaciones["Temp_Est2"][N-2] - dataframeEstaciones["Temp_Est2"][N-3] +
      dataframeEstaciones["Temp_Est3"][N-2] - dataframeEstaciones["Temp_Est3"][N-3] +
      dataframeEstaciones["Temp_Est4"][N-2] - dataframeEstaciones["Temp_Est4"][N-3])/3
m2 = (dataframeEstaciones["Temp_Est2"][N-1] - dataframeEstaciones["Temp_Est2"][N-2] +
      dataframeEstaciones["Temp_Est3"][N-1] - dataframeEstaciones["Temp_Est3"][N-2] +
      dataframeEstaciones["Temp_Est4"][N-1] - dataframeEstaciones["Temp_Est4"][N-2])/3
dataframeEstaciones["Temp_NASA"][N-2] = dataframeEstaciones["Temp_NASA"][N-3] + m1
dataframeEstaciones["Temp_NASA"][N-1] = dataframeEstaciones["Temp_NASA"][N-2] + m2
dataframeEstaciones
# Out:
#                      Temp_Est2  Temp_Est3  Temp_Est4  Temp_NASA
# datetime
# 2019-05-01 00:00:00        NaN        NaN        NaN  20.198735
# 2019-05-01 01:00:00        NaN        NaN        NaN  19.953091
# 2019-05-01 02:00:00        NaN        NaN        NaN  19.707447
# 2019-05-01 03:00:00        NaN        NaN        NaN  19.461803
# 2019-05-01 04:00:00        NaN        NaN        NaN  19.490947
# ...                        ...        ...        ...        ...
# 2021-12-31 19:00:00  36.075000  34.866667  35.658333  40.044972
# 2021-12-31 20:00:00  34.508333  33.775000  34.000000  38.845231
# 2021-12-31 21:00:00  33.233333  32.575000  33.108333  37.645491
# 2021-12-31 22:00:00  31.925000  31.708333  32.116667  36.589935
# 2021-12-31 23:00:00  30.966667  30.608333  31.275000  35.623268
#
# [23424 rows x 4 columns]

# %%
print("En la Estación 2 faltan "+str(dataframeEstaciones["Temp_Est2"].isna().sum())+" datos.")
print("En la Estación 3 faltan "+str(dataframeEstaciones["Temp_Est3"].isna().sum())+" datos.")
print("En la Estación 4 faltan "+str(dataframeEstaciones["Temp_Est4"].isna().sum())+" datos.")
print("En la NASA faltan "+str(dataframeEstaciones["Temp_NASA"].isna().sum())+" datos.")
##Llegado a este punto, se puede crear una nueva columna con el cual se tendrá el promedio de los valores que no sean NaN
# Out:
# En la Estación 2 faltan 771 datos.
# En la Estación 3 faltan 633 datos.
# En la Estación 4 faltan 578 datos.
# En la NASA faltan 0 datos.

# %%
N
# Out:
# 23424

# %%
##Se crea una nueva columna que contandrá el promedio de los datos de las estaciones
dataframeEstaciones["Promedio"] = np.zeros([N,1])

# %%
##Para cada fila, se halla el promedio de los valores.
for i in range(0,N):
    n = 1
    val = dataframeEstaciones["Temp_NASA"][i]
    if(dataframeEstaciones["Temp_Est2"].isna()[i]==False):
        val = val + dataframeEstaciones["Temp_Est2"][i]
        n = n + 1
    if(dataframeEstaciones["Temp_Est3"].isna()[i]==False):
        val = val + dataframeEstaciones["Temp_Est3"][i]
        n = n + 1
    if(dataframeEstaciones["Temp_Est4"].isna()[i]==False):
        val = val + dataframeEstaciones["Temp_Est4"][i]
        n = n + 1
    val = val/n
    dataframeEstaciones["Promedio"][i] = val

# %%
##Se grafican los conjuntos de datos del promedio y de la NASA.
dataframeEstaciones["Promedio"].plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
dataframeEstaciones["Temp_NASA"].plot( marker='.',markersize=1, linestyle='None', alpha=0.6, figsize=(15, 4))
plt.title('Conjunto de Datos')
plt.xlabel('Fecha')
plt.ylabel('Temperatura (°C)')
plt.legend(['Promedio','NASA'],loc='upper right')
plt.show
plt.savefig("Imagenes/EstProm_NASAinterp_Res1H.png")

# %%
##Ahora, se agruparán los datos en X e Y. Para ello será necesario definir el window: puntos temporales de entrada, y step:
#puntos temporales de salida.
window = 24*14
step = 24*1
X_est = np.zeros([N-step-window+1,window])
Y_est = np.zeros([N-step-window+1,step])
X_NASA = np.zeros([N-step-window+1,window])
Y_NASA = np.zeros([N-step-window+1,step])

for i in range(0,N-step-window+1):
    X_est[i][range(0,window)] = dataframeEstaciones["Promedio"][range(i,i+window)]
    Y_est[i][range(0,step)] = dataframeEstaciones["Promedio"][range(i+window,i+window+step)]
    X_NASA[i][range(0,window)] = dataframeEstaciones["Temp_NASA"][range(i,i+window)]
    Y_NASA[i][range(0,step)] = dataframeEstaciones["Temp_NASA"][range(i+window,i+window+step)]

##Ahora que se tienen los conjuntos de datos de entrada y salida, se procederá a separar en conjuntos de entrenamiento y prueba.

# %%
dias = 180
X_est_train = X_est[range(0,(N-step-window+1)-24*(dias-1)-1)]
Y_est_train = Y_est[range(0,(N-step-window+1)-24*(dias-1)-1)]
X_est_test = X_est[range((N-step-window+1)-24*(dias-1)-1,(N-step-window+1))]
Y_est_test = Y_est[range((N-step-window+1)-24*(dias-1)-1,(N-step-window+1))]

X_NASA_train = X_NASA[range(0,(N-step-window+1)-24*(dias-1)-1)]
Y_NASA_train = Y_NASA[range(0,(N-step-window+1)-24*(dias-1)-1)]
X_NASA_test = X_NASA[range((N-step-window+1)-24*(dias-1)-1,(N-step-window+1))]
Y_NASA_test = Y_NASA[range((N-step-window+1)-24*(dias-1)-1,(N-step-window+1))]

##Para trabajar con RNN es neceario nromalizar valores para evitar problemas con
#los algoritmos. Para ello se asume un minimo de 0°C y máximo de 50°C para ambos
#conjuntos de datos
def normalizar(input):
  min = 0
  max = 50
  return (input-min)/(max-min)

def desnormalizar(input):
  min = 0
  max = 50
  return input*(max-min) + min

X_est_train_norm = normalizar(X_est_train)
Y_est_train_norm = normalizar(Y_est_train)
X_est_test_norm = normalizar(X_est_test)
Y_est_test_norm = normalizar(Y_est_test)

X_NASA_train_norm = normalizar(X_NASA_train)
Y_NASA_train_norm = normalizar(Y_NASA_train)
X_NASA_test_norm = normalizar(X_NASA_test)
Y_NASA_test_norm = normalizar(Y_NASA_test)

##Por último se hace un reshape de las entradas para que corresponda con el formato
#que debe recibir una RNN:
X_est_train_norm = np.asarray(np.reshape(X_est_train_norm, (X_est_train_norm.shape[0], window, 1)))
X_est_test_norm = np.asarray(np.reshape(X_est_test_norm, (X_est_test_norm.shape[0], window, 1)))
X_NASA_train_norm = np.asarray(np.reshape(X_NASA_train_norm, (X_NASA_train_norm.shape[0], window, 1)))
X_NASA_test_norm = np.asarray(np.reshape(X_NASA_test_norm, (X_NASA_test_norm.shape[0], window, 1)))

##Ahora con los datos separados, se puede proceder al diseño y entrenamiento de las redes

# %% [markdown]
# # Aprendizaje: Redes RNN

# %%
##Se crea el objeto de regresión lineal para los datos promediados
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import GRU
from keras.metrics import mean_squared_error
from timeit import default_timer as timer
n_neuronas = 6
neuronas = [30,32,34,36,38,40]
n_droprates = 8
droprates = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35]
n_batchsize = 1
batchsizes = 128
npred = n_neuronas*n_droprates

time = dataframeEstaciones.index[N-24*dias:N]
orig = np.array(dataframeEstaciones["Temp_NASA"][N-24*dias:N])

PrediccionesLSTM = np.zeros([npred,dias*24])
Tiempo_Entrenamiento = np.zeros(npred)

# %% [markdown]
# # Red LSTM

# %%
# %mkdir "Imagenes_1EFv2"
# %cd "Imagenes_1EFv2"
##Se procede a realizar el entrenamiento de las redes probando los hiperparámetros:
for neu in range(0,n_neuronas):
  for dro in range(0,n_droprates):
      time_start = timer()

      modeloLSTM = Sequential()
      modeloLSTM.add( LSTM(neuronas[neu], input_shape=[window,1], name='Capa_Entrada_Recursiva') )
      modeloLSTM.add( Dropout(rate = droprates[dro], name='Capa_Dropout') )
      modeloLSTM.add( Dense(step, activation='linear',name='Capa_De_Salida') )
      modeloLSTM.compile(loss='mean_absolute_error', optimizer='adam')
      #modeloLSTM.summary()
      historyLSTM = modeloLSTM.fit(X_NASA_train_norm,Y_NASA_train_norm, epochs=50, batch_size = batchsizes, verbose = 1, validation_split=0.1)
      #Y_est_pred = modeloLSTM.predict(X_est_test_norm)
      #print(metrics.mean_squared_error(Y_est_test_norm, Y_est_pred))
      ##Se hacen lo gráficos del historial evolutivo:
      plt.clf()
      plt.figure(figsize=(8,6))
      plt.plot(historyLSTM.history['loss'])
      plt.plot(historyLSTM.history['val_loss'])
      plt.title('Model Loss')
      plt.ylabel('loss')
      plt.xlabel('epoch')
      plt.legend(['train','validation'],loc='upper right')
      ##plt.show
      plt.savefig("LTSM_LossEst_Neuronas({})_Drop({}).png".format(neuronas[neu],droprates[dro]))
      plt.clf()
      ##Se procede a realizar el calculo de las predicciones para los ultimos 180 días que comprende el TEST:
      PredLSTM = np.zeros(dias*24);
      for i in range(0,24*dias,24):
        pred = modeloLSTM.predict(X_NASA_test_norm[i].reshape(1,window,1))
        PrediccionesLSTM[dro+neu*n_droprates][range(i,i+24)] = pred
      PrediccionesLSTM[dro+neu*n_droprates] = desnormalizar(PrediccionesLSTM[dro+neu*n_droprates])
      plt.figure(figsize=(15*12,5))
      plt.plot(time,PrediccionesLSTM[dro+neu*n_droprates])
      plt.plot(time,orig)
      plt.title('Predicción LSTM (Neuronas={}; Drop Rate={})'.format(neuronas[neu],droprates[dro]))
      plt.ylabel('Temperatura (°C)')
      plt.xlabel('Fecha')
      plt.legend(['Predicción','Mediciones Reales'],loc='upper right')
      #plt.show()
      plt.savefig("LTSM_Predic_Neuronas({})_Drop({}).png".format(neuronas[neu],droprates[dro]))
      plt.clf()

      time_end = timer()
      Tiempo_Entrenamiento[dro+neu*n_droprates] = time_end - time_start
# Out:
# mkdir: cannot create directory ‘Imagenes_1EFv2’: File exists
# /content/gdrive/MyDrive/Colab Notebooks/IA_Temperatura/Imagenes_1EFv2
# Epoch 1/50
# 132/132 [==============================] - 6s 16ms/step - loss: 0.1616 - val_loss: 0.0811
# Epoch 2/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0808 - val_loss: 0.0722
# Epoch 3/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0618 - val_loss: 0.0595
# Epoch 4/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0525 - val_loss: 0.0548
# Epoch 5/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0504 - val_loss: 0.0557
# Epoch 6/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0492 - val_loss: 0.0559
# Epoch 7/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0480 - val_loss: 0.0535
# Epoch 8/50
# 132/132 [==============================] - 1s 11ms/step - loss: 0.0473 - val_loss: 0.0521
# Epoch 9/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0465 - val_loss: 0.0494
# Epoch 10/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0460 - val_loss: 0.0485
# Epoch 11/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0455 - val_loss: 0.0482
# Epoch 12/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0450 - val_loss: 0.0484
# Epoch 13/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0445 - val_loss: 0.0479
# Epoch 14/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0441 - val_loss: 0.0479
# Epoch 15/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0440 - val_loss: 0.0455
# Epoch 16/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0437 - val_loss: 0.0482
# Epoch 17/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0435 - val_loss: 0.0456
# Epoch 18/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0436 - val_loss: 0.0457
# Epoch 19/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0431 - val_loss: 0.0466
# Epoch 20/50
# 132/132 [==============================] - 1s 11ms/step - loss: 0.0429 - val_loss: 0.0447
# Epoch 21/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0429 - val_loss: 0.0441
# Epoch 22/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0426 - val_loss: 0.0450
# Epoch 23/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0425 - val_loss: 0.0449
# Epoch 24/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0427 - val_loss: 0.0477
# Epoch 25/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0423 - val_loss: 0.0450
# Epoch 26/50
# 132/132 [==============================] - 1s 11ms/step - loss: 0.0423 - val_loss: 0.0432
# Epoch 27/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0423 - val_loss: 0.0441
# Epoch 28/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0420 - val_loss: 0.0444
# Epoch 29/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0419 - val_loss: 0.0452
# Epoch 30/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0419 - val_loss: 0.0456
# Epoch 31/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0419 - val_loss: 0.0440
# Epoch 32/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0419 - val_loss: 0.0441
# Epoch 33/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0417 - val_loss: 0.0486
# Epoch 34/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0417 - val_loss: 0.0429
# Epoch 35/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0416 - val_loss: 0.0444
# Epoch 36/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0416 - val_loss: 0.0440
# Epoch 37/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0414 - val_loss: 0.0443
# Epoch 38/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0414 - val_loss: 0.0445
# Epoch 39/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0413 - val_loss: 0.0469
# Epoch 40/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0414 - val_loss: 0.0435
# Epoch 41/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0413 - val_loss: 0.0452
# Epoch 42/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0414 - val_loss: 0.0444
# Epoch 43/50
# 132/132 [==============================] - 1s 11ms/step - loss: 0.0411 - val_loss: 0.0440
# Epoch 44/50
# 132/132 [==============================] - 1s 11ms/step - loss: 0.0410 - val_loss: 0.0423
# Epoch 45/50
# 132/132 [==============================] - 1s 11ms/step - loss: 0.0411 - val_loss: 0.0436
# Epoch 46/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0414 - val_loss: 0.0425
# Epoch 47/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0409 - val_loss: 0.0435
# Epoch 48/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0410 - val_loss: 0.0423
# Epoch 49/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0410 - val_loss: 0.0444
# Epoch 50/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0409 - val_loss: 0.0435
# 1/1 [==============================] - 0s 367ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/50
# 132/132 [==============================] - 4s 16ms/step - loss: 0.1775 - val_loss: 0.0825
# Epoch 2/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0929 - val_loss: 0.0766
# Epoch 3/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0757 - val_loss: 0.0616
# Epoch 4/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0621 - val_loss: 0.0561
# Epoch 5/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0582 - val_loss: 0.0518
# Epoch 6/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0560 - val_loss: 0.0504
# Epoch 7/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0547 - val_loss: 0.0510
# Epoch 8/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0539 - val_loss: 0.0533
# Epoch 9/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0528 - val_loss: 0.0491
# Epoch 10/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0519 - val_loss: 0.0507
# Epoch 11/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0514 - val_loss: 0.0495
# Epoch 12/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0508 - val_loss: 0.0515
# Epoch 13/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0504 - val_loss: 0.0503
# Epoch 14/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0495 - val_loss: 0.0467
# Epoch 15/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0492 - val_loss: 0.0502
# Epoch 16/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0486 - val_loss: 0.0463
# Epoch 17/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0481 - val_loss: 0.0471
# Epoch 18/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0475 - val_loss: 0.0457
# Epoch 19/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0472 - val_loss: 0.0464
# Epoch 20/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0469 - val_loss: 0.0454
# Epoch 21/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0465 - val_loss: 0.0464
# Epoch 22/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0462 - val_loss: 0.0452
# Epoch 23/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0459 - val_loss: 0.0449
# Epoch 24/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0458 - val_loss: 0.0449
# Epoch 25/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0456 - val_loss: 0.0463
# Epoch 26/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0455 - val_loss: 0.0457
# Epoch 27/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0451 - val_loss: 0.0455
# Epoch 28/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0449 - val_loss: 0.0442
# Epoch 29/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0447 - val_loss: 0.0436
# Epoch 30/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0445 - val_loss: 0.0450
# Epoch 31/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0443 - val_loss: 0.0461
# Epoch 32/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0446 - val_loss: 0.0453
# Epoch 33/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0440 - val_loss: 0.0447
# Epoch 34/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0439 - val_loss: 0.0443
# Epoch 35/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0438 - val_loss: 0.0448
# Epoch 36/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0437 - val_loss: 0.0448
# Epoch 37/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0435 - val_loss: 0.0444
# Epoch 38/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0434 - val_loss: 0.0429
# Epoch 39/50
# 132/132 [==============================] - 2s 11ms/step - loss: 0.0433 - val_loss: 0.0436
# Epoch 40/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0431 - val_loss: 0.0446
# Epoch 41/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0430 - val_loss: 0.0441
# Epoch 42/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0429 - val_loss: 0.0459
# Epoch 43/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0428 - val_loss: 0.0435
# Epoch 44/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0428 - val_loss: 0.0433
# Epoch 45/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0428 - val_loss: 0.0438
# Epoch 46/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0426 - val_loss: 0.0436
# Epoch 47/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0425 - val_loss: 0.0434
# Epoch 48/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0424 - val_loss: 0.0449
# Epoch 49/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0422 - val_loss: 0.0431
# Epoch 50/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0419 - val_loss: 0.0430
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Epoch 1/50
# 132/132 [==============================] - 4s 18ms/step - loss: 0.1631 - val_loss: 0.0813
# Epoch 2/50
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0976 - val_loss: 0.0783
# Epoch 3/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0820 - val_loss: 0.0636
# Epoch 4/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0676 - val_loss: 0.0556
# Epoch 5/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0626 - val_loss: 0.0521
# Epoch 6/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0596 - val_loss: 0.0503
# Epoch 7/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0572 - val_loss: 0.0501
# Epoch 8/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0559 - val_loss: 0.0502
# Epoch 9/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0545 - val_loss: 0.0502
# Epoch 10/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0536 - val_loss: 0.0519
# Epoch 11/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0526 - val_loss: 0.0497
# Epoch 12/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0521 - val_loss: 0.0485
# Epoch 13/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0512 - val_loss: 0.0498
# Epoch 14/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0507 - val_loss: 0.0479
# Epoch 15/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0501 - val_loss: 0.0487
# Epoch 16/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0496 - val_loss: 0.0478
# Epoch 17/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0491 - val_loss: 0.0481
# Epoch 18/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0485 - val_loss: 0.0481
# Epoch 19/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0479 - val_loss: 0.0466
# Epoch 20/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0476 - val_loss: 0.0476
# Epoch 21/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0472 - val_loss: 0.0471
# Epoch 22/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0467 - val_loss: 0.0447
# Epoch 23/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0463 - val_loss: 0.0463
# Epoch 24/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0461 - val_loss: 0.0461
# Epoch 25/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0460 - val_loss: 0.0460
# Epoch 26/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0455 - val_loss: 0.0448
# Epoch 27/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0453 - val_loss: 0.0441
# Epoch 28/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0452 - val_loss: 0.0444
# Epoch 29/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0450 - val_loss: 0.0446
# Epoch 30/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0448 - val_loss: 0.0441
# Epoch 31/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0446 - val_loss: 0.0446
# Epoch 32/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0445 - val_loss: 0.0450
# Epoch 33/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0444 - val_loss: 0.0445
# Epoch 34/50
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0442 - val_loss: 0.0451
# Epoch 35/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0439 - val_loss: 0.0446
# Epoch 36/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0440 - val_loss: 0.0435
# Epoch 37/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0439 - val_loss: 0.0443
# Epoch 38/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0437 - val_loss: 0.0440
# Epoch 39/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0436 - val_loss: 0.0440
# Epoch 40/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0434 - val_loss: 0.0446
# Epoch 41/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0436 - val_loss: 0.0442
# Epoch 42/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0433 - val_loss: 0.0445
# Epoch 43/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0431 - val_loss: 0.0439
# Epoch 44/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0430 - val_loss: 0.0442
# Epoch 45/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0431 - val_loss: 0.0444
# Epoch 46/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0430 - val_loss: 0.0449
# Epoch 47/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0428 - val_loss: 0.0438
# Epoch 48/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0429 - val_loss: 0.0436
# Epoch 49/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0427 - val_loss: 0.0436
# Epoch 50/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0427 - val_loss: 0.0436
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# Epoch 1/50
# 132/132 [==============================] - 4s 17ms/step - loss: 0.1756 - val_loss: 0.0814
# Epoch 2/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0998 - val_loss: 0.0729
# Epoch 3/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0796 - val_loss: 0.0589
# Epoch 4/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0689 - val_loss: 0.0540
# Epoch 5/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0639 - val_loss: 0.0546
# Epoch 6/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0608 - val_loss: 0.0520
# Epoch 7/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0588 - val_loss: 0.0503
# Epoch 8/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0572 - val_loss: 0.0530
# Epoch 9/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0559 - val_loss: 0.0522
# Epoch 10/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0549 - val_loss: 0.0521
# Epoch 11/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0539 - val_loss: 0.0523
# Epoch 12/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0530 - val_loss: 0.0505
# Epoch 13/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0523 - val_loss: 0.0520
# Epoch 14/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0519 - val_loss: 0.0514
# Epoch 15/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0515 - val_loss: 0.0513
# Epoch 16/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0507 - val_loss: 0.0497
# Epoch 17/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0504 - val_loss: 0.0501
# Epoch 18/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0499 - val_loss: 0.0492
# Epoch 19/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0497 - val_loss: 0.0481
# Epoch 20/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0494 - val_loss: 0.0507
# Epoch 21/50
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0491 - val_loss: 0.0481
# Epoch 22/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0488 - val_loss: 0.0485
# Epoch 23/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0486 - val_loss: 0.0488
# Epoch 24/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0482 - val_loss: 0.0483
# Epoch 25/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0477 - val_loss: 0.0478
# Epoch 26/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0473 - val_loss: 0.0486
# Epoch 27/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0472 - val_loss: 0.0473
# Epoch 28/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0466 - val_loss: 0.0460
# Epoch 29/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0464 - val_loss: 0.0458
# Epoch 30/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0460 - val_loss: 0.0451
# Epoch 31/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0459 - val_loss: 0.0460
# Epoch 32/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0457 - val_loss: 0.0455
# Epoch 33/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0455 - val_loss: 0.0456
# Epoch 34/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0456 - val_loss: 0.0465
# Epoch 35/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0455 - val_loss: 0.0441
# Epoch 36/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0451 - val_loss: 0.0446
# Epoch 37/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0451 - val_loss: 0.0447
# Epoch 38/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0449 - val_loss: 0.0448
# Epoch 39/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0447 - val_loss: 0.0438
# Epoch 40/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0446 - val_loss: 0.0428
# Epoch 41/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0445 - val_loss: 0.0452
# Epoch 42/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0445 - val_loss: 0.0444
# Epoch 43/50
# 132/132 [==============================] - 2s 12ms/step - loss: 0.0446 - val_loss: 0.0437
# Epoch 44/50
# 132/132 [==============================] - 2s 13ms/step - loss: 0.0442 - val_loss: 0.0455
# Epoch 45/50
# ...
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# Epoch 1/50
# 132/132 [==============================] - 6s 22ms/step - loss: 0.1866 - val_loss: 0.0816
# Epoch 2/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.1101 - val_loss: 0.0773
# Epoch 3/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0910 - val_loss: 0.0628
# Epoch 4/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0769 - val_loss: 0.0552
# Epoch 5/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0700 - val_loss: 0.0528
# Epoch 6/50
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0658 - val_loss: 0.0511
# Epoch 7/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0628 - val_loss: 0.0511
# Epoch 8/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0601 - val_loss: 0.0524
# Epoch 9/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0584 - val_loss: 0.0504
# Epoch 10/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0567 - val_loss: 0.0503
# Epoch 11/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0557 - val_loss: 0.0521
# Epoch 12/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0545 - val_loss: 0.0522
# Epoch 13/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0540 - val_loss: 0.0515
# Epoch 14/50
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0532 - val_loss: 0.0492
# Epoch 15/50
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0531 - val_loss: 0.0510
# Epoch 16/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0528 - val_loss: 0.0508
# Epoch 17/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0522 - val_loss: 0.0504
# Epoch 18/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0518 - val_loss: 0.0509
# Epoch 19/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0516 - val_loss: 0.0517
# Epoch 20/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0514 - val_loss: 0.0513
# Epoch 21/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0512 - val_loss: 0.0490
# Epoch 22/50
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0508 - val_loss: 0.0478
# Epoch 23/50
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0506 - val_loss: 0.0488
# Epoch 24/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0503 - val_loss: 0.0494
# Epoch 25/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0500 - val_loss: 0.0511
# Epoch 26/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0498 - val_loss: 0.0480
# Epoch 27/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0497 - val_loss: 0.0476
# Epoch 28/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0494 - val_loss: 0.0504
# Epoch 29/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0495 - val_loss: 0.0477
# Epoch 30/50
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0491 - val_loss: 0.0464
# Epoch 31/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0490 - val_loss: 0.0456
# Epoch 32/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0487 - val_loss: 0.0461
# Epoch 33/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0487 - val_loss: 0.0467
# Epoch 34/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0484 - val_loss: 0.0450
# Epoch 35/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0484 - val_loss: 0.0458
# Epoch 36/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0485 - val_loss: 0.0486
# Epoch 37/50
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0483 - val_loss: 0.0471
# Epoch 38/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0484 - val_loss: 0.0452
# Epoch 39/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0481 - val_loss: 0.0444
# Epoch 40/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0484 - val_loss: 0.0461
# Epoch 41/50
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0481 - val_loss: 0.0449
# Epoch 42/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0478 - val_loss: 0.0439
# Epoch 43/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0480 - val_loss: 0.0448
# Epoch 44/50
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0480 - val_loss: 0.0479
# Epoch 45/50
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0479 - val_loss: 0.0432
# Epoch 46/50
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0474 - val_loss: 0.0447
# Epoch 47/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0475 - val_loss: 0.0456
# Epoch 48/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0476 - val_loss: 0.0467
# Epoch 49/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0476 - val_loss: 0.0455
# Epoch 50/50
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0477 - val_loss: 0.0454
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step

# %%
##Ahora que se hicieron todas las predicciones necesarias, se hará una tabla
#donde se evaluará por medio de MSE cuál es el modelo que predijo mejor:
def mse(x,y):
  if (x.shape[0]!=y.shape[0]):
    raise NameError("Las entradas no tiene las mismas dimensiones")
  dif = x-y
  dif = np.abs(dif)
  sum = dif.sum()
  return sum/dif.shape[0]


tabla = pd.DataFrame(np.zeros([npred,4]),columns=['Neuronas','Drop Rate', 'MAE', 'Tiempo'])
tabla.head()
for i in range(0,n_neuronas):
  for j in range(0,n_droprates):
      tabla["Neuronas"][j+i*n_droprates] = neuronas[i]
      tabla["Drop Rate"][j+i*n_droprates] = droprates[j]
      tabla["MAE"][j+i*n_droprates] = mse(orig,PrediccionesLSTM[j+i*n_droprates])
      tabla["Tiempo"][j+i*n_droprates] = Tiempo_Entrenamiento[j+i*n_droprates]

# %%
tabla
# Out:
#     Neuronas  Drop Rate       MAE      Tiempo
# 0       30.0       0.00  2.172441  103.782553
# 1       30.0       0.05  2.220340  159.071150
# 2       30.0       0.10  2.221707  105.594277
# 3       30.0       0.15  2.261773  107.800541
# 4       30.0       0.20  2.247574  159.781160
# 5       30.0       0.25  2.353472  159.419712
# 6       30.0       0.30  2.338071  160.870652
# 7       30.0       0.35  2.269928  160.137819
# 8       32.0       0.00  2.263928  117.112379
# 9       32.0       0.05  2.235963  161.235979
# 10      32.0       0.10  2.212377  159.583676
# 11      32.0       0.15  2.226199  158.643379
# 12      32.0       0.20  2.192632  108.524374
# 13      32.0       0.25  2.268507  159.663211
# 14      32.0       0.30  2.237713  111.006075
# 15      32.0       0.35  2.276256  114.004516
# 16      34.0       0.00  2.137349  159.729851
# 17      34.0       0.05  2.165959  159.900180
# 18      34.0       0.10  2.206074  160.927156
# 19      34.0       0.15  2.215927  161.785765
# 20      34.0       0.20  2.198947  125.142439
# 21      34.0       0.25  2.272220  162.210736
# 22      34.0       0.30  2.243825  163.117734
# 23      34.0       0.35  2.284680  161.756131
# 24      36.0       0.00  2.216955  129.866775
# 25      36.0       0.05  2.208577  161.245992
# 26      36.0       0.10  2.187208  161.823267
# 27      36.0       0.15  2.254627  128.187109
# 28      36.0       0.20  2.257470  162.139925
# 29      36.0       0.25  2.330796  162.053943
# 30      36.0       0.30  2.353922  131.803320
# 31      36.0       0.35  2.268101  130.624287
# 32      38.0       0.00  2.186368  163.864688
# 33      38.0       0.05  2.219463  161.775078
# 34      38.0       0.10  2.205707  162.317704
# 35      38.0       0.15  2.241903  161.596179
# 36      38.0       0.20  2.193875  129.142166
# 37      38.0       0.25  2.244318  162.107267
# 38      38.0       0.30  2.270622  132.066866
# 39      38.0       0.35  2.260455  161.737377
# 40      40.0       0.00  2.219581  163.260682
# 41      40.0       0.05  2.250434  130.620173
# 42      40.0       0.10  2.180853  162.187920
# 43      40.0       0.15  2.180703  161.272607
# 44      40.0       0.20  2.261787  162.573536
# 45      40.0       0.25  2.220458  161.230863
# 46      40.0       0.30  2.258395  162.395833
# 47      40.0       0.35  2.259150  161.778685

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
indexMin = 0
minMSE = tabla["MAE"][0]
for i in range(1,npred):
  if(tabla["MAE"][i] < minMSE):
    minMSE = tabla["MAE"][i]
    indexMin = i

# %%
indexMin
# Out:
# 16

# %%
# %cd ..
tabla.to_csv("Tabla de Resultados 1Fv2p2.csv",index=False,header=False)
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/IA_Temperatura

# %%
tabla.iloc[indexMin]
# Out:
# Neuronas      34.000000
# Drop Rate      0.000000
# MAE            2.137349
# Tiempo       159.729851
# Name: 16, dtype: float64
